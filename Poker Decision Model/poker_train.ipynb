# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.transforms as v2

import poker_model as pm
from poker_dataset import PokerDataset

# %%
filepath = r'C:\Users\kctak\Documents\Code\PokerAI\APS360 Progress\poker_data'
dataset = PokerDataset(filepath, "IlxxxlI")

# Define fraction of the entire dataset for training and validation
train_frac, val_frac = 0.7, 0.15
test_frac = 1 - train_frac - val_frac # The rest is for testing.

# Randomly split the dataset
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_frac, val_frac, test_frac])
print(f"Train Dataset Length: {len(train_dataset)}, \nValidation Dataset Length: {len(val_dataset)}, \nTest Dataset Length: {len(test_dataset)}")
# Out:
# Parsing Games: 100%|██████████| 52154/52154 [00:10<00:00, 4789.81it/s]
# Train Dataset Length: 35465,
# Validation Dataset Length: 7600,
# Test Dataset Length: 7599

# %%
hidden_shape = [64, 32]
learning_rate = 0.001
batch_size = 512
num_epochs = 30

losses, accs = pm.train_with_hyperparameters(train_dataset, val_dataset, hidden_shape, learning_rate, batch_size, \
                                            num_epochs=num_epochs, display_progress=True)
# Out:
# Epochs:   3%|▎         | 1/30 [00:19<09:28, 19.62s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0035331580159224827, 	 Train accuracy:	 0.6201325250246722
# Valid loss:	 0.00012363213457559284, 	 Valid accuracy:	 0.7705263157894737
# Epochs:   7%|▋         | 2/30 [00:38<08:50, 18.95s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0015534051295212827, 	 Train accuracy:	 0.7764274636966023
# Valid loss:	 9.361750985446729e-05, 	 Valid accuracy:	 0.7739473684210526
# Epochs:  10%|█         | 3/30 [00:56<08:28, 18.83s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0013065381479014568, 	 Train accuracy:	 0.7982799943606372
# Valid loss:	 8.382412948106464e-05, 	 Valid accuracy:	 0.8155263157894737
# Epochs:  13%|█▎        | 4/30 [01:15<08:11, 18.91s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0011916821915223033, 	 Train accuracy:	 0.8298604257718878
# Valid loss:	 7.872797156635084e-05, 	 Valid accuracy:	 0.8330263157894737
# Epochs:  17%|█▋        | 5/30 [01:35<08:02, 19.29s/it]
# -----------------------------------------------------------------
# Train loss:	 0.001131956497973823, 	 Train accuracy:	 0.8386578316650218
# Valid loss:	 7.586639178426643e-05, 	 Valid accuracy:	 0.8323684210526315
# Epochs:  20%|██        | 6/30 [01:55<07:50, 19.59s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0010933394965173561, 	 Train accuracy:	 0.8395601297053433
# Valid loss:	 7.393277789417066e-05, 	 Valid accuracy:	 0.834078947368421
# Epochs:  23%|██▎       | 7/30 [02:16<07:38, 19.94s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0010707396723463423, 	 Train accuracy:	 0.8408289863245453
# Valid loss:	 7.269449924167834e-05, 	 Valid accuracy:	 0.8336842105263158
# Epochs:  27%|██▋       | 8/30 [02:35<07:08, 19.47s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0010499356782236373, 	 Train accuracy:	 0.8415903002960665
# Valid loss:	 7.148766203930504e-05, 	 Valid accuracy:	 0.835
# Epochs:  30%|███       | 9/30 [02:53<06:44, 19.25s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0010271200361632333, 	 Train accuracy:	 0.841900465247427
# Valid loss:	 7.004050047774064e-05, 	 Valid accuracy:	 0.8364473684210526
# Epochs:  33%|███▎      | 10/30 [03:12<06:21, 19.08s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0010022147155927365, 	 Train accuracy:	 0.8437614549555901
# Valid loss:	 6.910901320608039e-05, 	 Valid accuracy:	 0.8363157894736842
# Epochs:  37%|███▋      | 11/30 [03:32<06:10, 19.49s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0009887239256715903, 	 Train accuracy:	 0.8448611306922318
# Valid loss:	 6.771588796063473e-05, 	 Valid accuracy:	 0.8372368421052632
# Epochs:  40%|████      | 12/30 [03:53<05:57, 19.84s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0009684290869790946, 	 Train accuracy:	 0.8466375299591146
# Valid loss:	 6.668943323587117e-05, 	 Valid accuracy:	 0.838421052631579
# Epochs:  43%|████▎     | 13/30 [04:13<05:38, 19.93s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0009461705764997465, 	 Train accuracy:	 0.8502749189341604
# Valid loss:	 6.54717377926174e-05, 	 Valid accuracy:	 0.8417105263157895
# Epochs:  47%|████▋     | 14/30 [04:33<05:20, 20.02s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0009228638511575968, 	 Train accuracy:	 0.853771323840406
# Valid loss:	 6.459447506226992e-05, 	 Valid accuracy:	 0.8446052631578947
# Epochs:  50%|█████     | 15/30 [04:54<05:01, 20.09s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0009123303658969309, 	 Train accuracy:	 0.85628084026505
# Valid loss:	 6.360882206967002e-05, 	 Valid accuracy:	 0.8453947368421053
# Epochs:  53%|█████▎    | 16/30 [05:14<04:41, 20.11s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008984224384197072, 	 Train accuracy:	 0.8596644579162555
# Valid loss:	 6.250907715998198e-05, 	 Valid accuracy:	 0.848421052631579
# Epochs:  57%|█████▋    | 17/30 [05:35<04:23, 20.30s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008721812183490916, 	 Train accuracy:	 0.8618356125757789
# Valid loss:	 6.2015048767391e-05, 	 Valid accuracy:	 0.8478947368421053
# Epochs:  60%|██████    | 18/30 [05:55<04:03, 20.29s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008569613996151051, 	 Train accuracy:	 0.8640631608628225
# Valid loss:	 6.102939185343291e-05, 	 Valid accuracy:	 0.8482894736842105
# Epochs:  63%|██████▎   | 19/30 [06:15<03:42, 20.27s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008461094475693315, 	 Train accuracy:	 0.8653884111095447
# Valid loss:	 6.0249810156069305e-05, 	 Valid accuracy:	 0.8501315789473685
# Epochs:  67%|██████▋   | 20/30 [06:36<03:23, 20.38s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008279316561120901, 	 Train accuracy:	 0.8686028478781898
# Valid loss:	 5.9819817543029786e-05, 	 Valid accuracy:	 0.8514473684210526
# Epochs:  70%|███████   | 21/30 [06:57<03:05, 20.64s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008167731145129762, 	 Train accuracy:	 0.870576624841393
# Valid loss:	 6.0023524259266104e-05, 	 Valid accuracy:	 0.8523684210526316
# Epochs:  73%|███████▎  | 22/30 [07:17<02:43, 20.42s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008026737345301952, 	 Train accuracy:	 0.8716199069505146
# Valid loss:	 5.876359970946061e-05, 	 Valid accuracy:	 0.8553947368421052
# Epochs:  77%|███████▋  | 23/30 [07:35<02:19, 19.86s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0008001129179835807, 	 Train accuracy:	 0.8735372902861976
# Valid loss:	 5.8553512943418406e-05, 	 Valid accuracy:	 0.8564473684210526
# Epochs:  80%|████████  | 24/30 [07:53<01:55, 19.28s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007799907109136728, 	 Train accuracy:	 0.8759904130833216
# Valid loss:	 5.805897085290206e-05, 	 Valid accuracy:	 0.8592105263157894
# Epochs:  83%|████████▎ | 25/30 [08:12<01:35, 19.04s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007776204485592747, 	 Train accuracy:	 0.8774566473988439
# Valid loss:	 5.7729086593577736e-05, 	 Valid accuracy:	 0.8594736842105263
# Epochs:  87%|████████▋ | 26/30 [08:30<01:14, 18.73s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007622626433499555, 	 Train accuracy:	 0.8790356689694064
# Valid loss:	 5.759809362260919e-05, 	 Valid accuracy:	 0.8575
# Epochs:  90%|█████████ | 27/30 [08:48<00:55, 18.64s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007563751010754944, 	 Train accuracy:	 0.8796841956858875
# Valid loss:	 5.7189354771061945e-05, 	 Valid accuracy:	 0.859078947368421
# Epochs:  93%|█████████▎| 28/30 [09:06<00:36, 18.47s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007460567580784693, 	 Train accuracy:	 0.8817989567178909
# Valid loss:	 5.694444634412464e-05, 	 Valid accuracy:	 0.8603947368421052
# Epochs:  97%|█████████▋| 29/30 [09:24<00:18, 18.28s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007413857396291305, 	 Train accuracy:	 0.8834061751022134
# Valid loss:	 5.655940033887562e-05, 	 Valid accuracy:	 0.8638157894736842
# Epochs: 100%|██████████| 30/30 [09:42<00:00, 19.43s/it]
# -----------------------------------------------------------------
# Train loss:	 0.0007266712301324995, 	 Train accuracy:	 0.8850133934865361
# Valid loss:	 5.7132565661480555e-05, 	 Valid accuracy:	 0.8602631578947368

# %%
pm.plot_curve(losses['Train'], losses['Validation'], "Losses")
pm.plot_curve(accs['Train'], accs['Validation'], "Accuracy")

# %%
hidden_shapes = [[64, 32], [128, 64], [256, 128]]
learning_rates = [0.01, 0.001, 0.0001]
batch_sizes = [32, 64, 128]

acc_graphs, labels = pm.tuning_hyperparameters(train_dataset, val_dataset, batch_sizes, learning_rates, hidden_shapes, num_epochs=50)

# %%
import pickle
# Save plot data
with open('acc_graphs.pkl', 'wb') as f:
    pickle.dump(acc_graphs, f)

with open('labels.pkl', 'wb') as f:
    pickle.dump(labels, f)

# %%
pm.plot_train_valid_list(acc_graphs, labels)

# %%
pm.display_train_valid_list(acc_graphs, labels)
# Out:
#                                                                Labels     Train     Valid
# 0       Batch Size: 64, Learning Rate: 0.001,\n Hidden Size: [64, 32]  0.938427  0.874908
# 1      Batch Size: 128, Learning Rate: 0.001,\n Hidden Size: [64, 32]  0.924946  0.874461
# 2       Batch Size: 32, Learning Rate: 0.001,\n Hidden Size: [64, 32]  0.944449  0.868382
# 3     Batch Size: 128, Learning Rate: 0.001,\n Hidden Size: [128, 64]  0.956109  0.867868
# 4    Batch Size: 32, Learning Rate: 0.0001,\n Hidden Size: [256, 128]  0.929268  0.867671
# 5       Batch Size: 128, Learning Rate: 0.01,\n Hidden Size: [64, 32]  0.949065  0.864711
# 6    Batch Size: 64, Learning Rate: 0.0001,\n Hidden Size: [256, 128]  0.902941  0.863684
# 7     Batch Size: 64, Learning Rate: 0.001,\n Hidden Size: [256, 128]  0.983764  0.862987
# 8      Batch Size: 64, Learning Rate: 0.001,\n Hidden Size: [128, 64]  0.970963  0.862671
# 9    Batch Size: 128, Learning Rate: 0.001,\n Hidden Size: [256, 128]  0.980152  0.861066
# 10    Batch Size: 32, Learning Rate: 0.0001,\n Hidden Size: [128, 64]  0.887185  0.860816
# 11       Batch Size: 32, Learning Rate: 0.01,\n Hidden Size: [64, 32]  0.935796  0.860789
# 12    Batch Size: 32, Learning Rate: 0.001,\n Hidden Size: [256, 128]  0.985391  0.860421
# 13     Batch Size: 32, Learning Rate: 0.001,\n Hidden Size: [128, 64]  0.976876  0.859658
# 14     Batch Size: 32, Learning Rate: 0.01,\n Hidden Size: [256, 128]  0.963956  0.857526
# 15       Batch Size: 64, Learning Rate: 0.01,\n Hidden Size: [64, 32]  0.941779  0.856474
# 16     Batch Size: 128, Learning Rate: 0.01,\n Hidden Size: [128, 64]  0.974175  0.854526
# 17      Batch Size: 32, Learning Rate: 0.01,\n Hidden Size: [128, 64]  0.957719  0.853868
# 18     Batch Size: 64, Learning Rate: 0.01,\n Hidden Size: [256, 128]  0.973991  0.853408
# 19      Batch Size: 64, Learning Rate: 0.01,\n Hidden Size: [128, 64]  0.967585  0.853316
# 20    Batch Size: 128, Learning Rate: 0.01,\n Hidden Size: [256, 128]  0.979399  0.852408
# 21  Batch Size: 128, Learning Rate: 0.0001,\n Hidden Size: [256, 128]  0.876182  0.851816
# 22    Batch Size: 64, Learning Rate: 0.0001,\n Hidden Size: [128, 64]  0.867224  0.850013
# 23     Batch Size: 32, Learning Rate: 0.0001,\n Hidden Size: [64, 32]  0.861689  0.847434
# 24   Batch Size: 128, Learning Rate: 0.0001,\n Hidden Size: [128, 64]  0.857671  0.843395
# 25     Batch Size: 64, Learning Rate: 0.0001,\n Hidden Size: [64, 32]  0.853690  0.842855
# 26    Batch Size: 128, Learning Rate: 0.0001,\n Hidden Size: [64, 32]  0.847334  0.839895
